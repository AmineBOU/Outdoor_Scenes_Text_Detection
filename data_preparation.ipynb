# %%
import numpy as np
import cv2, skimage
import matplotlib.pyplot as plt

# %%
data_path = "data/train/"
img = cv2.imread(data_path + 'IMG_0064.JPG')

boxs = open(data_path + 'IMG_0064.gt').read().split('\n')
boxs.pop()
# Out:
# ''

# %%
rect = boxs[0].split()
rect
# Out:
# ['0', '0', '614', '574', '262', '41', '-0.303571']

# %%
fl

# %%
# 
skimage.io.imshow(img)

plt.show()

# %%
import numpy as np
import cv2
 
# Create a black image
img = np.zeros((512,512,3), np.uint8)

# %%
rect = cv2.rectangle(img,(384,0),(510,128),(0,255,0),3)
skimage.io.imshow(rect)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:77: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
